# %%
baseurl = "http://api.weatherapi.com/v1"
becky_key = "d93addfd6a01469991c200836261705" #put your own here
#key= <your api key>

# %%
# http://api.weatherapi.com/v1/current.json?key=<YOUR_API_KEY>&q=London

# %%
import requests
import pandas as pd

# %%
city = "Prestonsburg"
baseurl = f"http://api.weatherapi.com/v1/current.json?key={becky_key}&q={city}"
response = requests.get(baseurl)

# %%
response.status_code
# Out:
# 200

# %%
data = response.json()
data
# Out:
# {'location': {'name': 'Prestonsburg',
#   'region': 'Kentucky',
#   'country': 'United States of America',
#   'lat': 37.6656,
#   'lon': -82.7717,
#   'tz_id': 'America/New_York',
#   'localtime_epoch': 1779057562,
#   'localtime': '2026-05-17 18:39'},
#  'current': {'last_updated_epoch': 1779057000,
#   'last_updated': '2026-05-17 18:30',
#   'temp_c': 32.1,
#   'temp_f': 89.9,
#   'is_day': 1,
#   'condition': {'text': 'Sunny',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#    'code': 1000},
#   'wind_mph': 7.2,
#   'wind_kph': 11.5,
#   'wind_degree': 211,
#   'wind_dir': 'SSW',
#   'pressure_mb': 1016.0,
#   'pressure_in': 30.01,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 30,
#   'cloud': 0,
#   'feelslike_c': 31.3,
#   'feelslike_f': 88.4,
#   'windchill_c': 32.1,
#   'windchill_f': 89.9,
#   'heatindex_c': 31.3,
#   'heatindex_f': 88.4,
#   'dewpoint_c': 12.5,
#   'dewpoint_f': 54.5,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'uv': 1.8,
# ...

# %%
current = data['current']
location = data['location']
temp_f = current['temp_f']
wind_mph = current['wind_mph']
humidity = current['humidity']

# %%
temp_f, humidity
# Out:
# (89.9, 30)

# %%
def get_weather(city):
    url = f"http://api.weatherapi.com/v1/current.json?key={becky_key}&q={city}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        current = data['current']
        location = data['location']
        temp_f = current['temp_f']
        wind_mph = current['wind_mph']
        humidity = current['humidity']
        print(f"Weather for {location['name']}, {location['region']}")
        print(f"Temperature: {current['temp_f']}°F / {current['temp_c']} °C")
        print(f"Condition: {current['condition']['text']}")
        print(f"Humidity: {current['humidity']}%")
        print(f"Wind Speed: {current['wind_mph']}mph")
    else:
        print(f"Error fetching data for{city}: {response.status_code}")

# %%
get_weather("Prestonsburg")
# Out:
# Weather for Prestonsburg, Kentucky
# Temperature: 89.9°F / 32.1 °C
# Condition: Sunny
# Humidity: 30%
# Wind Speed: 7.2mph

# %%
get_weather("Lexington")
# Out:
# Weather for Lexington-Fayette, Kentucky
# Temperature: 86.4°F / 30.2 °C
# Condition: Sunny
# Humidity: 39%
# Wind Speed: 6.7mph

# %%
cities = ["Prestonsburg", "Louisville", "Morehead", "Paintsville", "New York" ]
weather_data = []
for city in cities:
    url = f"http://api.weatherapi.com/v1/current.json?key={becky_key}&q={city}"
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        weather_data.append({
            "City": data['location']['name'],
            "Temperature": data['current']['temp_f'],
            "Condition": data['current']['condition']['text'],
            "Humidity": data['current']['humidity'],
            "Wind Speed": data['current']['wind_mph']})
    else:
        print("Error fetching data")

# %%
weather_data
# Out:
# [{'City': 'Prestonsburg',
#   'Temperature': 89.9,
#   'Condition': 'Sunny',
#   'Humidity': 30,
#   'Wind Speed': 7.2},
#  {'City': 'Louisville',
#   'Temperature': 87.1,
#   'Condition': 'Sunny',
#   'Humidity': 39,
#   'Wind Speed': 8.9},
#  {'City': 'Morehead',
#   'Temperature': 78.1,
#   'Condition': 'Partly Cloudy',
#   'Humidity': 89,
#   'Wind Speed': 5.4},
#  {'City': 'Paintsville',
#   'Temperature': 88.0,
#   'Condition': 'Sunny',
#   'Humidity': 36,
#   'Wind Speed': 6.9},
#  {'City': 'New York',
#   'Temperature': 90.0,
#   'Condition': 'Partly cloudy',
#   'Humidity': 30,
#   'Wind Speed': 9.4}]

# %%
weather_df = pd.DataFrame(weather_data)

# %%
weather_df.head()
# Out:
#            City  Temperature      Condition  Humidity  Wind Speed
# 0  Prestonsburg         89.9          Sunny        30         7.2
# 1    Louisville         87.1          Sunny        39         8.9
# 2      Morehead         78.1  Partly Cloudy        89         5.4
# 3   Paintsville         88.0          Sunny        36         6.9
# 4      New York         90.0  Partly cloudy        30         9.4

# %%
weather_df.to_csv("sample_weather_data.csv", index=False)
