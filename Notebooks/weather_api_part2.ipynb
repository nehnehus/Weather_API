# %%
import requests
import pandas as pd
from datetime import datetime
import os
from dotenv import load_dotenv
load_dotenv()
api_key = os.getenv('api_key')

# %%
baseurl = "http://api.weatherapi.com/v1"
# f"http://api.weatherapi.com/v1/current.json?key={api_key}&q={city}"
city = "Louisville"

# %%
response = requests.get(f"http://api.weatherapi.com/v1/current.json?key={api_key}&q={city}")
response.status_code
# Out:
# 401

# %%
data = response.json()
data['current']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 2
#       1 data = response.json()
# ----> 2 data['current']
#
# KeyError: 'current'

# %%
forecast_url = f"{baseurl}forecast.json?key={api_key}&q={city}&days=3"
forecast_response = requests.get(forecast_url)
forecast_response.status_code
# Out:
# 404

# %%
forecast_data = forecast_response.json()
forecast = forecast_data['forecast']['forecastday']
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\BECKY\AppData\Local\Programs\Python\Python314\Lib\site-packages\requests\models.py:1117, in Response.json(self, **kwargs)
#    1116 try:
# -> 1117     return complexjson.loads(self.text, **kwargs)
#    1118 except JSONDecodeError as e:
#    1119     # Catch JSON-related errors and raise as requests.JSONDecodeError
#    1120     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File c:\Users\BECKY\AppData\Local\Programs\Python\Python314\Lib\json\__init__.py:352, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     349 if (cls is None and object_hook is None and
#     350         parse_int is None and parse_float is None and
#     351         parse_constant is None and object_pairs_hook is None and not kw):
# ...

# %%
forecast_3_days_summary = [] 
for day in forecast:
    forecast_3_days_summary.append(f"{day['date']['max_temp_f']}F -{day['day']['condition']['text']}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 forecast_3_days_summary = []
# ----> 2 for day in forecast:
#       3     forecast_3_days_summary.append(f"{day['date']['max_temp_f']}F -{day['day']['condition']['text']}")
#
# NameError: name 'forecast' is not defined

# %%
forecast_3_days_summary
# Out:
# []

# %%
forecast_3_days_summary = []
for day in forecast:
    date_obj = datetime.strptime(day['date'], '%Y-%m-%d')
    formatted_date = date_obj.strftime('%A, %B, %#d')
    forecast_3_days_summary.append(f"{formatted_date}:")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 forecast_3_days_summary = []
# ----> 2 for day in forecast:
#       3     date_obj = datetime.strptime(day['date'], '%Y-%m-%d')
#
# NameError: name 'forecast' is not defined

# %%
today = pd.TimeStamp.now().strftime('%Y-%m-%d')
atronomy_url = f"{baseurl}astronomy.json?key={api_key}&q={city}&dt={today}"

# %%
def get_city_data(city, api_key):
    #get current weather
    #get a forecast
    #get astronomical data
    #get anything else you want
    #build a summary for the city
    #save that summary into a dictionary
    #build a summary for a city, save that summary into dictionary
